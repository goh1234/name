# %%
from sklearn.datasets import load_iris

# %%
import pandas as pd

# %%
iris = load_iris()

# %%
feature = iris['data']

# %%
labels = iris['target']

# %%
feature_names = iris['feature_names']

# %%
df = pd.DataFrame(feature, columns=feature_names)

# %%
df['target'] = labels

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# !pip3 install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
plt.figure(figsize=(10,7))

sns.scatterplot(data=df, x = 'sepal length (cm)', y = 'sepal width (cm)', 
                hue=df['target'], palette = 'viridis')

plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
mapping = {'male' : 0, 'female' : 1}

# %%
df['Sex'].map(mapping)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    1
# 889    0
# 890    0
# Name: Sex, Length: 891, dtype: int64

# %%
df['Sex'] = df['Sex'].map(mapping)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis = 1, inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    0  22.0      1      0   7.2500        S
# 1         1       1    1  38.0      1      0  71.2833        C
# 2         1       3    1  26.0      0      0   7.9250        S
# 3         1       1    1  35.0      1      0  53.1000        S
# 4         0       3    0  35.0      0      0   8.0500        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].mode()[0]
# Out:
# np.float64(24.0)

# %%
df['Age'].fillna(df['Age'].mode()[0])
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    24.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mode()[0])

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    0  22.0      1      0   7.2500        S
# 1           1       1    1  38.0      1      0  71.2833        C
# 2           1       3    1  26.0      0      0   7.9250        S
# 3           1       1    1  35.0      1      0  53.1000        S
# 4           0       3    0  35.0      0      0   8.0500        S
# ..        ...     ...  ...   ...    ...    ...      ...      ...
# 886         0       2    0  27.0      0      0  13.0000        S
# 887         1       1    1  19.0      0      0  30.0000        S
# 888         0       3    1  24.0      1      2  23.4500        S
# 889         1       1    0  26.0      0      0  30.0000        C
# 890         0       3    0  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Embarked'].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
embarked_mapping = {'Q':0, 'S':1, 'C':2}
df['Embarked'].map(embarked_mapping)
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 886    1
# 887    1
# 888    1
# 889    2
# 890    0
# Name: Embarked, Length: 891, dtype: int64

# %%
df['Embarked'] = df['Embarked'].map(embarked_mapping)

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         1
# 1           1       1    1  38.0      1      0  71.2833         2
# 2           1       3    1  26.0      0      0   7.9250         1
# 3           1       1    1  35.0      1      0  53.1000         1
# 4           0       3    0  35.0      0      0   8.0500         1
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         1
# 887         1       1    1  19.0      0      0  30.0000         1
# 888         0       3    1  24.0      1      2  23.4500         1
# 889         1       1    0  26.0      0      0  30.0000         2
# 890         0       3    0  32.0      0      0   7.7500         0
#
# [891 rows x 8 columns]

# %%
df['Age'].skew()
# Out:
# np.float64(0.6577529069911331)

# %%
for col in df.columns:
    print(col)
# Out:
# Survived
# Pclass
# Sex
# Age
# SibSp
# Parch
# Fare
# Embarked

# %%
for col in df.columns:
    print(f'skewness of {col} is', df['col'].skew())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 2
# ...

# %%
plt.figure(figsize = (4,10))
sns.boxplot(df['Fare'])
plt.show()

# %%
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)

print(Q1,Q3)
# Out:
# 7.9104 31.0

# %%
IQR = Q3 - Q1

# %%
whisker_width = 1.5
lower_whisker = Q1 - whisker_width * IQR
upper_whisker = Q3 + whisker_width * IQR

print(lower_whisker, upper_whisker)
# Out:
# -26.724 65.6344

# %%
df['Fare'] < lower_whisker
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df['Fare'] > upper_whisker
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
(df['Fare'] < lower_whisker) | (df['Fare'] > upper_whisker)
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[(df['Fare'] < lower_whisker) | (df['Fare'] > upper_whisker)]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 1           1       1    1  38.0      1      0   71.2833         2
# 27          0       1    0  19.0      3      2  263.0000         1
# 31          1       1    1  24.0      1      0  146.5208         2
# 34          0       1    0  28.0      1      0   82.1708         2
# 52          1       1    1  49.0      1      0   76.7292         2
# ..        ...     ...  ...   ...    ...    ...       ...       ...
# 846         0       3    0  24.0      8      2   69.5500         1
# 849         1       1    1  24.0      1      0   89.1042         2
# 856         1       1    1  45.0      1      1  164.8667         1
# 863         0       3    1  24.0      8      2   69.5500         1
# 879         1       1    1  56.0      0      1   83.1583         2
#
# [116 rows x 8 columns]

# %%
(df['Fare'] > lower_whisker) & (df['Fare'] < upper_whisker)
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889     True
# 890     True
# Name: Fare, Length: 891, dtype: bool

# %%
df[(df['Fare'] > lower_whisker) & (df['Fare'] < upper_whisker)]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         1
# 2           1       3    1  26.0      0      0   7.9250         1
# 3           1       1    1  35.0      1      0  53.1000         1
# 4           0       3    0  35.0      0      0   8.0500         1
# 5           0       3    0  24.0      0      0   8.4583         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         1
# 887         1       1    1  19.0      0      0  30.0000         1
# 888         0       3    1  24.0      1      2  23.4500         1
# 889         1       1    0  26.0      0      0  30.0000         2
# 890         0       3    0  32.0      0      0   7.7500         0
#
# [775 rows x 8 columns]

# %%
df = df[(df['Fare'] > lower_whisker) & (df['Fare'] < upper_whisker)]

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         1
# 2           1       3    1  26.0      0      0   7.9250         1
# 3           1       1    1  35.0      1      0  53.1000         1
# 4           0       3    0  35.0      0      0   8.0500         1
# 5           0       3    0  24.0      0      0   8.4583         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         0       2    0  27.0      0      0  13.0000         1
# 887         1       1    1  19.0      0      0  30.0000         1
# 888         0       3    1  24.0      1      2  23.4500         1
# 889         1       1    0  26.0      0      0  30.0000         2
# 890         0       3    0  32.0      0      0   7.7500         0
#
# [775 rows x 8 columns]

# %%
df = df.reset_index()

# %%
df
# Out:
#      index  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0        0         0       3    0  22.0      1      0   7.2500         1
# 1        2         1       3    1  26.0      0      0   7.9250         1
# 2        3         1       1    1  35.0      1      0  53.1000         1
# 3        4         0       3    0  35.0      0      0   8.0500         1
# 4        5         0       3    0  24.0      0      0   8.4583         0
# ..     ...       ...     ...  ...   ...    ...    ...      ...       ...
# 770    886         0       2    0  27.0      0      0  13.0000         1
# 771    887         1       1    1  19.0      0      0  30.0000         1
# 772    888         0       3    1  24.0      1      2  23.4500         1
# 773    889         1       1    0  26.0      0      0  30.0000         2
# 774    890         0       3    0  32.0      0      0   7.7500         0
#
# [775 rows x 9 columns]

# %%
df.iloc[:, 1:]
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         1
# 1           1       3    1  26.0      0      0   7.9250         1
# 2           1       1    1  35.0      1      0  53.1000         1
# 3           0       3    0  35.0      0      0   8.0500         1
# 4           0       3    0  24.0      0      0   8.4583         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 770         0       2    0  27.0      0      0  13.0000         1
# 771         1       1    1  19.0      0      0  30.0000         1
# 772         0       3    1  24.0      1      2  23.4500         1
# 773         1       1    0  26.0      0      0  30.0000         2
# 774         0       3    0  32.0      0      0   7.7500         0
#
# [775 rows x 8 columns]

# %%
df = df.iloc[:, 1:]

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       3    0  22.0      1      0   7.2500         1
# 1           1       3    1  26.0      0      0   7.9250         1
# 2           1       1    1  35.0      1      0  53.1000         1
# 3           0       3    0  35.0      0      0   8.0500         1
# 4           0       3    0  24.0      0      0   8.4583         0
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 770         0       2    0  27.0      0      0  13.0000         1
# 771         1       1    1  19.0      0      0  30.0000         1
# 772         0       3    1  24.0      1      2  23.4500         1
# 773         1       1    0  26.0      0      0  30.0000         2
# 774         0       3    0  32.0      0      0   7.7500         0
#
# [775 rows x 8 columns]

# %%
for col in df.columns:
    print(f'skewness of {col} is {df[col].skew()}')
# Out:
# skewness of Survived is 0.6798738387603496
# skewness of Pclass is -1.0295968890475515
# skewness of Sex is 0.7988800220538848
# skewness of Age is 0.6845730984053457
# skewness of SibSp is 2.7906891466584316
# skewness of Parch is 3.145570664583091
# skewness of Fare is 1.4306715336945985
# skewness of Embarked is 0.11733953621182389

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  775 non-null    int64
#  1   Pclass    775 non-null    int64
#  2   Sex       775 non-null    int64
#  3   Age       775 non-null    float64
#  4   SibSp     775 non-null    int64
#  5   Parch     775 non-null    int64
#  6   Fare      775 non-null    float64
#  7   Embarked  775 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 48.6 KB

# %%
for col in df.columns:
    print(f'Skewness of {col} is {df[col].skew()}')
# Out:
# Skewness of Survived is 0.6798738387603496
# Skewness of Pclass is -1.0295968890475515
# Skewness of Sex is 0.7988800220538848
# Skewness of Age is 0.6845730984053457
# Skewness of SibSp is 2.7906891466584316
# Skewness of Parch is 3.145570664583091
# Skewness of Fare is 1.4306715336945985
# Skewness of Embarked is 0.11733953621182389

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
scaler = StandardScaler()

# %%
df['Fare']
# Out:
# 0       7.2500
# 1       7.9250
# 2      53.1000
# 3       8.0500
# 4       8.4583
#         ...
# 770    13.0000
# 771    30.0000
# 772    23.4500
# 773    30.0000
# 774     7.7500
# Name: Fare, Length: 775, dtype: float64

# %%
np.array(df['Fare'])
# Out:
# array([ 7.25  ,  7.925 , 53.1   ,  8.05  ,  8.4583, 51.8625, 21.075 ,
#        11.1333, 30.0708, 16.7   , 26.55  ,  8.05  , 31.275 ,  7.8542,
#        16.    , 29.125 , 13.    , 18.    ,  7.225 , 26.    , 13.    ,
#         8.0292, 35.5   , 21.075 , 31.3875,  7.225 ,  7.8792,  7.8958,
#        27.7208,  7.75  , 10.5   , 52.    ,  7.2292,  8.05  , 18.    ,
#        11.2417,  9.475 , 21.    ,  7.8958, 41.5792,  7.8792,  8.05  ,
#        15.5   ,  7.75  , 21.6792, 17.8   , 39.6875,  7.8   , 26.    ,
#        61.9792, 35.5   , 10.5   ,  7.2292, 27.75  , 46.9   ,  7.2292,
#        27.9   , 27.7208, 15.2458, 10.5   ,  8.1583,  7.925 ,  8.6625,
#        10.5   , 46.9   , 14.4542, 56.4958,  7.65  ,  7.8958,  8.05  ,
#        29.    , 12.475 ,  9.    ,  9.5   ,  7.7875, 47.1   , 10.5   ,
#        15.85  , 34.375 ,  8.05  ,  8.05  ,  8.05  ,  7.8542, 61.175 ,
#        20.575 ,  7.25  ,  8.05  , 34.6542, 63.3583, 23.    , 26.    ,
# ...

# %%
arr = np.array([1,2,3,4,5,6])

# %%
arr.shape
# Out:
# (6,)

# %%
arr.reshape(3,2).shape
# Out:
# (3, 2)

# %%
np.array(df['Fare']).shape
# Out:
# (775,)

# %%
np.array(df['Fare']).reshape(-1,1).shape
# Out:
# (775, 1)

# %%
scaled_arr = scaler.fit_transform(np.array(df['Fare']).reshape(-1,1))

# %%
scaled_arr.flatten().shape
# Out:
# (775,)

# %%
pd.Series(scaled_arr.flatten())
# Out:
# 0     -0.779117
# 1     -0.729373
# 2      2.599828
# 3     -0.720161
# 4     -0.690071
#          ...
# 770   -0.355367
# 771    0.897459
# 772    0.414752
# 773    0.897459
# 774   -0.742269
# Length: 775, dtype: float64

# %%
df['Fare'] = pd.Series(scaled_arr.flatten())

# %%
df
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0           0       3    0  22.0      1      0 -0.779117         1
# 1           1       3    1  26.0      0      0 -0.729373         1
# 2           1       1    1  35.0      1      0  2.599828         1
# 3           0       3    0  35.0      0      0 -0.720161         1
# 4           0       3    0  24.0      0      0 -0.690071         0
# ..        ...     ...  ...   ...    ...    ...       ...       ...
# 770         0       2    0  27.0      0      0 -0.355367         1
# 771         1       1    1  19.0      0      0  0.897459         1
# 772         0       3    1  24.0      1      2  0.414752         1
# 773         1       1    0  26.0      0      0  0.897459         2
# 774         0       3    0  32.0      0      0 -0.742269         0
#
# [775 rows x 8 columns]

# %%
import scipy.stats as stats

# %%
age_array = np.array(df['Age'])

# %%
age_array
# Out:
# array([22.  , 26.  , 35.  , 35.  , 24.  , 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 14.  , 55.  ,  2.  , 24.  , 31.  ,
#        24.  , 35.  , 34.  , 15.  , 28.  ,  8.  , 38.  , 24.  , 24.  ,
#        24.  , 40.  , 24.  , 66.  , 42.  , 24.  , 21.  , 18.  , 14.  ,
#        40.  , 27.  , 24.  ,  3.  , 19.  , 24.  , 24.  , 24.  , 24.  ,
#        18.  ,  7.  , 21.  , 29.  , 65.  , 24.  , 21.  , 28.5 ,  5.  ,
#        11.  , 22.  ,  4.  , 24.  , 24.  , 29.  , 19.  , 17.  , 26.  ,
#        32.  , 16.  , 26.  , 32.  , 25.  , 24.  , 24.  ,  0.83, 30.  ,
#        22.  , 29.  , 24.  , 28.  , 17.  , 33.  , 16.  , 24.  , 24.  ,
#        29.  , 20.  , 46.  , 26.  , 59.  , 24.  , 71.  , 23.  , 34.  ,
#        34.  , 28.  , 24.  , 33.  , 37.  , 28.  , 21.  , 24.  , 38.  ,
#        24.  , 47.  , 14.5 , 22.  , 20.  , 17.  , 21.  , 70.5 , 29.  ,
#         2.  , 24.  , 32.5 , 32.5 , 12.  , 24.  , 24.  , 24.  , 45.  ,
# ...

# %%
stats.kstest(age_array, 'norm', args = (age_array.mean(), age_array.std()))
# Out:
# KstestResult(statistic=np.float64(0.1428123983369468), pvalue=np.float64(2.959440445338335e-14), statistic_location=np.float64(24.0), statistic_sign=np.int8(1))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df['Age'] = pd.Series(scaler.fit_transform(age_array.reshape(-1,1)).flatten())

# %%
df
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0           0       3    0  0.271174      1      0 -0.779117         1
# 1           1       3    1  0.321438      0      0 -0.729373         1
# 2           1       1    1  0.434531      1      0  2.599828         1
# 3           0       3    0  0.434531      0      0 -0.720161         1
# 4           0       3    0  0.296306      0      0 -0.690071         0
# ..        ...     ...  ...       ...    ...    ...       ...       ...
# 770         0       2    0  0.334004      0      0 -0.355367         1
# 771         1       1    1  0.233476      0      0  0.897459         1
# 772         0       3    1  0.296306      1      2  0.414752         1
# 773         1       1    0  0.321438      0      0  0.897459         2
# 774         0       3    0  0.396833      0      0 -0.742269         0
#
# [775 rows x 8 columns]

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         3    0  0.271174      1      0 -0.779117         1
# 1         3    1  0.321438      0      0 -0.729373         1
# 2         1    1  0.434531      1      0  2.599828         1
# 3         3    0  0.434531      0      0 -0.720161         1
# 4         3    0  0.296306      0      0 -0.690071         0
# ..      ...  ...       ...    ...    ...       ...       ...
# 770       2    0  0.334004      0      0 -0.355367         1
# 771       1    1  0.233476      0      0  0.897459         1
# 772       3    1  0.296306      1      2  0.414752         1
# 773       1    0  0.321438      0      0  0.897459         2
# 774       3    0  0.396833      0      0 -0.742269         0
#
# [775 rows x 7 columns]

# %%
features = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]

# %%
target = df['Survived']

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 770    0
# 771    1
# 772    0
# 773    1
# 774    0
# Name: Survived, Length: 775, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, target)

# %%
train_features
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 578       3    0  0.296306      0      0 -0.740427         1
# 735       3    0  0.434531      0      0 -0.731524         2
# 285       1    1  0.195778      0      1  2.959404         2
# 142       3    0  0.371701      0      0 -0.720161         1
# 91        3    1  0.346569      0      0 -0.731524         1
# ..      ...  ...       ...    ...    ...       ...       ...
# 547       1    0  1.000000      0      0  0.897459         1
# 87        1    0  0.886906      0      0  1.240453         2
# 412       1    0  0.296306      0      0  2.518763         1
# 79        3    0  0.296306      0      0 -0.720161         1
# 630       2    1  0.371701      3      0  0.234198         1
#
# [581 rows x 7 columns]

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, target, test_size = 0.15)

# %%
len(train_features)
# Out:
# 658

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, target, test_size = 0.15, random_state = 2026)

# %%
train_features
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 253       1    0  0.296306      0      0  0.602676         1
# 56        3    0  0.044986      3      2  0.742698         1
# 322       3    1  0.032420      3      1  0.239725         1
# 338       3    1  0.384267      0      0 -0.734590         1
# 439       3    0  0.346569      0      0  0.346584         1
# ..      ...  ...       ...    ...    ...       ...       ...
# 541       3    0  0.258608      0      0 -0.734590         1
# 333       2    1  0.208344      0      0 -0.429063         2
# 77        3    1  0.409399      3      0 -0.145335         1
# 390       1    0  0.371701      0      0  0.731644         2
# 257       2    0  0.522493      0      0 -0.355367         1
#
# [658 rows x 7 columns]

# %%
train, test = train_test_split(df)

# %%
train
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 149         1       3    0  0.107816      0      2  0.199193         1
# 449         1       2    1  0.447097      1      0  0.602676         1
# 235         0       1    0  0.497361      0      0 -1.313411         1
# 605         1       3    1  0.296306      0      0 -0.743500         0
# 598         1       1    0  0.384267      1      0  2.887241         1
# ..        ...     ...  ...       ...    ...    ...       ...       ...
# 18          1       3    1  0.296306      0      0 -0.780959         2
# 403         0       2    0  0.296306      0      0 -1.313411         1
# 134         0       2    0  0.453380      0      2  0.602676         1
# 584         1       2    0  0.384267      0      0 -0.355367         1
# 382         1       2    1  0.346569      0      0 -0.355367         1
#
# [581 rows x 8 columns]

# %%
train.iloc[:, 1:]
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 149       3    0  0.107816      0      2  0.199193         1
# 449       2    1  0.447097      1      0  0.602676         1
# 235       1    0  0.497361      0      0 -1.313411         1
# 605       3    1  0.296306      0      0 -0.743500         0
# 598       1    0  0.384267      1      0  2.887241         1
# ..      ...  ...       ...    ...    ...       ...       ...
# 18        3    1  0.296306      0      0 -0.780959         2
# 403       2    0  0.296306      0      0 -1.313411         1
# 134       2    0  0.453380      0      2  0.602676         1
# 584       2    0  0.384267      0      0 -0.355367         1
# 382       2    1  0.346569      0      0 -0.355367         1
#
# [581 rows x 7 columns]

# %%
train.iloc[:, 0:]
# Out:
#      Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 149         1       3    0  0.107816      0      2  0.199193         1
# 449         1       2    1  0.447097      1      0  0.602676         1
# 235         0       1    0  0.497361      0      0 -1.313411         1
# 605         1       3    1  0.296306      0      0 -0.743500         0
# 598         1       1    0  0.384267      1      0  2.887241         1
# ..        ...     ...  ...       ...    ...    ...       ...       ...
# 18          1       3    1  0.296306      0      0 -0.780959         2
# 403         0       2    0  0.296306      0      0 -1.313411         1
# 134         0       2    0  0.453380      0      2  0.602676         1
# 584         1       2    0  0.384267      0      0 -0.355367         1
# 382         1       2    1  0.346569      0      0 -0.355367         1
#
# [581 rows x 8 columns]
