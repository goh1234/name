# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1.0, -2.0])
w = np.array([[0.5, -1.0, 2.0],
              [1.5,  0.0, -0.5]])
b = np.array([0.1, -0.2, 0.3])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def relu(x):
    return np.maximum(0, x)

# %%
def step(x):
    return (x>0).astype(int)

# %%
sigmoid(x)
# Out:
# array([0.73105858, 0.11920292])

# %%
sigmoid(w)
# Out:
# array([[0.62245933, 0.26894142, 0.88079708],
#        [0.81757448, 0.5       , 0.37754067]])

# %%
sigmoid(b)
# Out:
# array([0.52497919, 0.450166  , 0.57444252])

# %%
relu(x)
# Out:
# array([1., 0.])

# %%
relu(w)
# Out:
# array([[0.5, 0. , 2. ],
#        [1.5, 0. , 0. ]])

# %%
relu(b)
# Out:
# array([0.1, 0. , 0.3])

# %%
step(x)
# Out:
# array([1, 0])

# %%
step(w)
# Out:
# array([[1, 0, 1],
#        [1, 0, 0]])

# %%
step(b)
# Out:
# array([1, 0, 1])

# %%
y_observed = [0.06, 0.8, 0.11, 0.65, 0.34, 0.5, 0.74, 0.62, 0.4]
y_predicted = [0.05, 0.9, 0.1, 0.6, 0.2, 0.8, 0.3, 0.7, 0.5]

# %%
def mse(y_observed, y_predicted):
    y_observed_array = np.array(y_observed)
    y_predicted_array = np.array(y_predicted)
    return np.mean((y_observed_array - y_predicted_array)**2)

# %%
mse(y_observed, y_predicted)
# Out:
# np.float64(0.03692222222222222)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_observed, y_predicted)
# Out:
# 0.03692222222222222
